# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
banks = pd.read_csv('datasets/BANKS-large.csv')

# %%
banks.head()
# Out:
#          Date         HDFC        AXIS       ICICI        KOTAK         SBI  \
# 0  2021-03-10  1549.045776  760.750000  623.773560  1962.975220  384.153320
# 1  2021-03-12  1545.262085  750.599976  611.060791  1934.189575  377.613678
# 2  2021-03-15  1522.062500  744.400024  601.738098  1917.697754  380.388062
# 3  2021-03-16  1505.633667  737.750000  593.213074  1902.255371  375.086975
# 4  2021-03-17  1488.906006  727.900024  587.778931  1867.422607  364.782135
#
#          UBI        PNB     INDUSIND     BANDHAN        RBL       IDBI  \
# 0  37.849998  41.500000  1034.747681  348.518799  69.500000  38.250000
# 1  37.650002  41.049999  1017.632141  348.020477  69.699997  42.000000
# 2  36.950001  40.799999  1033.553589  338.253571  72.150002  40.349998
# 3  36.450001  39.799999  1029.622925  338.353241  77.000000  38.650002
# 4  35.150002  38.400002  1003.999329  334.765381  76.790001  35.849998
#
#        CANARA        BOI      INDIAN    UCO
# 0  161.199997  76.949997  132.861130  13.00
# 1  157.000000  75.849998  129.608597  13.40
# 2  158.300003  73.599998  125.025475  14.05
# 3  157.550003  71.949997  122.807838  14.05
# 4  150.250000  68.599998  114.627220  13.70

# %%
banks = banks.drop(["Date"], axis=1)

# %% [markdown]
# ## Correlation Analysis

# %%
corr = banks.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col0,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col1,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col2,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row3_col3,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row4_col4,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row5_col5,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row6_col6,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row7_col7,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row8_col8,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row9_col9,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row10_col10,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row11_col11,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col12,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row13_col13,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row14_col14{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col1{
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col2,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col7{
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col3,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row7_col0{
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col4{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col5{
#             background-color:  #569dc8;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col6{
#             background-color:  #94b6d7;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col7,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row11_col13{
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col8,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col9{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col9{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col10,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col3,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row3_col11{
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col11{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col12{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col13,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row6_col1,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row10_col0,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row14_col10{
#             background-color:  #3b92c1;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row0_col14{
#             background-color:  #4897c4;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col0,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row4_col3{
#             background-color:  #167bb6;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col2,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row6_col0{
#             background-color:  #328dbf;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col3{
#             background-color:  #60a1ca;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col4,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row6_col3,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row6_col7,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row14_col1{
#             background-color:  #348ebf;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col5,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row9_col13{
#             background-color:  #a4bcda;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col6,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row9_col14{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col8,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row7_col8{
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col9,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row9_col6{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col10,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col11,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row7_col12,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row9_col2{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col12{
#             background-color:  #9ab8d8;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col13,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row7_col10{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row1_col14,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row14_col12{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col0{
#             background-color:  #4295c3;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col1,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row13_col1{
#             background-color:  #67a4cc;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col4,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row4_col2{
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col5{
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col6,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row3_col12{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col7,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row13_col12{
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col8,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row8_col9,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row8_col14,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row9_col1,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row11_col7,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row11_col12,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col0,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col2,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col3,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col4,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col5,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col6,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col10,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col11,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row12_col13{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col9,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row7_col5,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row8_col1{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col10,#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row5_col13{
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col11{
#             background-color:  #045382;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col12{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col13{
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }#T_75c2cad9_82c8_11ed_a06a_f4d10803b971row2_col14{
#             background-color:

# %% [markdown]
# ## Data Preparation

# %%
X = banks.drop(["HDFC"], axis=1)
Y = banks.HDFC

# %% [markdown]
# ## Train-test split

# %%
(X_train, X_test, y_train, y_test) = train_test_split(X,Y,test_size=0.5,random_state=1)

# %% [markdown]
# # Ridge Regression

# %%
# Fitting a ridge regression for specific value of alpha (lambda)
# CASE1 : Choosing small lambda

ridge1 = Ridge(alpha=2, normalize=True, fit_intercept=True)
ridge1.fit(X_train, y_train)

print('intercept :- ', ridge1.intercept_)
print(pd.Series(ridge1.coef_, index=X.columns))
# Out:
# intercept :-  848.9209776305045
# AXIS        0.200160
# ICICI       0.055929
# KOTAK       0.071558
# SBI         0.047756
# UBI         0.046564
# PNB         1.778129
# INDUSIND    0.111831
# BANDHAN     0.040602
# RBL         0.156361
# IDBI        0.871565
# CANARA     -0.020876
# BOI        -0.186874
# INDIAN      0.153318
# UCO         5.199469
# dtype: float64

# %%
pred1 = ridge1.predict(X_test)
mean_squared_error(y_test, pred1)
# Out:
# 1809.2379800894676

# %%
# Fitting a ridge regression for specific value of alpha (lambda)
# CASE2 : Choosing high lambda value

ridge2 = Ridge(alpha=10e10, normalize=True, fit_intercept=True)
ridge2.fit(X_train, y_train)

print('intercept :- ', ridge2.intercept_)
print(pd.Series(ridge2.coef_, index=X.columns))
# Out:
# intercept :-  1511.7623028210005
# AXIS        1.161651e-11
# ICICI       5.165839e-12
# KOTAK       4.257674e-12
# SBI         6.825697e-12
# UBI         5.001916e-11
# PNB         1.681534e-10
# INDUSIND    5.723939e-12
# BANDHAN     1.830370e-12
# RBL         7.971310e-12
# IDBI        6.706497e-11
# CANARA      5.825068e-12
# BOI        -1.416236e-11
# INDIAN      2.316079e-11
# UCO         4.221405e-10
# dtype: float64

# %%
pred2 = ridge2.predict(X_test)
mean_squared_error(y_test, pred2)
# Out:
# 4559.431450719523

# %% [markdown]
# ## Choosing the optimal alpha/lambda

# %%
# For many alphas
# creating a grid for alpha 
alphas = 10**np.linspace(10,-2,100)
alphas
# Out:
# array([1.00000000e+10, 7.56463328e+09, 5.72236766e+09, 4.32876128e+09,
#        3.27454916e+09, 2.47707636e+09, 1.87381742e+09, 1.41747416e+09,
#        1.07226722e+09, 8.11130831e+08, 6.13590727e+08, 4.64158883e+08,
#        3.51119173e+08, 2.65608778e+08, 2.00923300e+08, 1.51991108e+08,
#        1.14975700e+08, 8.69749003e+07, 6.57933225e+07, 4.97702356e+07,
#        3.76493581e+07, 2.84803587e+07, 2.15443469e+07, 1.62975083e+07,
#        1.23284674e+07, 9.32603347e+06, 7.05480231e+06, 5.33669923e+06,
#        4.03701726e+06, 3.05385551e+06, 2.31012970e+06, 1.74752840e+06,
#        1.32194115e+06, 1.00000000e+06, 7.56463328e+05, 5.72236766e+05,
#        4.32876128e+05, 3.27454916e+05, 2.47707636e+05, 1.87381742e+05,
#        1.41747416e+05, 1.07226722e+05, 8.11130831e+04, 6.13590727e+04,
#        4.64158883e+04, 3.51119173e+04, 2.65608778e+04, 2.00923300e+04,
#        1.51991108e+04, 1.14975700e+04, 8.69749003e+03, 6.57933225e+03,
#        4.97702356e+03, 3.76493581e+03, 2.84803587e+03, 2.15443469e+03,
#        1.62975083e+03, 1.23284674e+03, 9.32603347e+02, 7.05480231e+02,
#        5.33669923e+02, 4.03701726e+02, 3.05385551e+02, 2.31012970e+02,
#        1.74752840e+02, 1.32194115e+02, 1.00000000e+02, 7.56463328e+01,
#        5.72236766e+01, 4.32876128e+01, 3.27454916e+01, 2.47707636e+01,
#        1.87381742e+01, 1.41747416e+01, 1.07226722e+01, 8.11130831e+00,
#        6.13590727e+00, 4.64158883e+00, 3.51119173e+00, 2.65608778e+00,
#        2.00923300e+00, 1.51991108e+00, 1.14975700e+00, 8.69749003e-01,
#        6.57933225e-01, 4.97702356e-01, 3.76493581e-01, 2.84803587e-01,
#        2.15443469e-01, 1.62975083e-01, 1.23284674e-01, 9.32603347e-02,
#        7.05480231e-02, 5.33669923e-02, 4.03701726e-02, 3.05385551e-02,
#        2.31012970e-02, 1.74752840e-02, 1.32194115e-02, 1.00000000e-02])

# %%
# fitting ridge regression model for each alpha
ridge = Ridge(normalize=True, fit_intercept=True)
coefs = []

for a in alphas:
    ridge.set_params(alpha = a)
    ridge.fit(X_train, y_train)
    coefs.append(ridge.coef_)

# %%
# coefficients
np.shape(coefs)
# Out:
# (100, 14)

# %%
alphas[28]
# Out:
# 4037017.2585965497

# %%
coefs[28]
# Out:
# array([ 2.87749403e-07,  1.27961547e-07,  1.05465695e-07,  1.69077377e-07,
#         1.23900957e-06,  4.16528136e-06,  1.41786191e-07,  4.53396690e-08,
#         1.97455144e-07,  1.66124777e-06,  1.44290958e-07, -3.50811615e-07,
#         5.73709209e-07,  1.04567261e-05])

# %% [markdown]
# ### Choosing the optimal alpha for ridge regression

# %% [markdown]
# Choosing lambda
#
# 1. Let us consider a grid for lambda(l1,l2,...., lk)
# 2. for l in lambda:
#     3. fit a ridge regression model
#     4. validate model using CV
# 5. choose l for which the validation error is the smallest

# %%
# identifying the best alpha
ridgecv = RidgeCV(alphas = alphas, normalize=True, fit_intercept=True)
ridgecv.fit(X_train, y_train)
ridgecv.alpha_
# Out:
# 0.017475284000076828

# %%
# MSE for chosen alpha
ridge4 = Ridge(alpha = ridgecv.alpha_, normalize=True, fit_intercept=True)
ridge4.fit(X_train, y_train)

mean_squared_error(y_test, ridge4.predict(X_test))
# Out:
# 664.177910042078

# %%
# fit the model on entire data
ridge4.fit(X, Y)
pd.Series(ridge4.coef_, index= X.columns)
# Out:
# AXIS        0.595938
# ICICI       0.267448
# KOTAK       0.099346
# SBI        -0.152092
# UBI        -0.322681
# PNB        -0.150249
# INDUSIND    0.256057
# BANDHAN     0.189765
# RBL         1.033953
# IDBI        4.560812
# CANARA     -0.275945
# BOI        -0.407420
# INDIAN     -1.210915
# UCO         4.845295
# dtype: float64
